# %%
from model.cae import AutoEncoder, training, load_best_model,
import torch
from torch.utils.data import TensorDataset, DataLoader, random_split
import matplotlib.pyplot as plt
from util.load_data import load_images_as_tensor

# %%
positive = load_images_as_tensor("/blue/iruchkin/pansiyuan/positive/")


print(positive.shape)

full_ds = TensorDataset(positive)

val_sz = max(1, int(0.05 * len(full_ds)))
train_sz = len(full_ds) - val_sz
train_ds, val_ds = random_split(full_ds, [train_sz, val_sz])

train_ld = DataLoader(train_ds, batch_size=64, shuffle=True, num_workers=4, pin_memory=True, drop_last=True)
val_ld   = DataLoader(val_ds,   batch_size=64, shuffle=False, num_workers=4, pin_memory=True)


negative = TensorDataset(load_images_as_tensor("/blue/iruchkin/pansiyuan/negative/images/"))
negative = DataLoader(negative,   batch_size=64, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# torch.Size([1324, 3, 256, 256])

# %%
model = AutoEncoder(in_channels=3, base_ch=32)
# model

# %%
out = training(model, train_ld, val_ld,
            epochs=150,lr=1e-2,
            outdir="runs/ae1024_tensor",
            loss_mix=0)
print("Best ckpt:", out['best_ckpt'])
# Out:
# [train] Epoch 1/150
#   train: mse=0.009453  mae=0.061811
#   valid: mse=0.006103  mae=0.050523  psnr=22.15 dB
#   ↑ new best (mse 0.006103) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 2/150
#   train: mse=0.006436  mae=0.051527
#   valid: mse=0.005959  mae=0.048906  psnr=22.26 dB
#   ↑ new best (mse 0.005959) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 3/150
#   train: mse=0.006359  mae=0.050891
#   valid: mse=0.005925  mae=0.049430  psnr=22.28 dB
#   ↑ new best (mse 0.005925) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 4/150
#   train: mse=0.006352  mae=0.050873
#   valid: mse=0.005920  mae=0.049576  psnr=22.29 dB
#   ↑ new best (mse 0.005920) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 5/150
#   train: mse=0.006356  mae=0.050978
#   valid: mse=0.005944  mae=0.050389  psnr=22.27 dB
#
# [train] Epoch 6/150
#   train: mse=0.006358  mae=0.050937
#   valid: mse=0.005935  mae=0.050191  psnr=22.27 dB
#
# [train] Epoch 7/150
#   train: mse=0.006349  mae=0.051080
#   valid: mse=0.005933  mae=0.048909  psnr=22.28 dB
#
# [train] Epoch 8/150
#   train: mse=0.006372  mae=0.050887
#   valid: mse=0.005925  mae=0.048750  psnr=22.28 dB
#
# [train] Epoch 9/150
#   train: mse=0.006319  mae=0.050729
#   valid: mse=0.005936  mae=0.049210  psnr=22.27 dB
#
# [train] Epoch 10/150
#   train: mse=0.006305  mae=0.050918
#   valid: mse=0.005908  mae=0.048955  psnr=22.30 dB
#   ↑ new best (mse 0.005908) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 11/150
#   train: mse=0.006306  mae=0.050558
#   valid: mse=0.005893  mae=0.049163  psnr=22.31 dB
#   ↑ new best (mse 0.005893) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 12/150
#   train: mse=0.006277  mae=0.050500
#   valid: mse=0.005898  mae=0.048718  psnr=22.30 dB
#
# [train] Epoch 13/150
#   train: mse=0.006235  mae=0.050373
#   valid: mse=0.005885  mae=0.048749  psnr=22.31 dB
#   ↑ new best (mse 0.005885) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 14/150
#   train: mse=0.006193  mae=0.050125
#   valid: mse=0.005799  mae=0.048453  psnr=22.38 dB
#   ↑ new best (mse 0.005799) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 15/150
#   train: mse=0.006047  mae=0.049798
#   valid: mse=0.005544  mae=0.048123  psnr=22.57 dB
#   ↑ new best (mse 0.005544) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 16/150
#   train: mse=0.005760  mae=0.048674
#   valid: mse=0.005353  mae=0.046232  psnr=22.73 dB
#   ↑ new best (mse 0.005353) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 17/150
#   train: mse=0.005705  mae=0.048722
#   valid: mse=0.005258  mae=0.048202  psnr=22.80 dB
#   ↑ new best (mse 0.005258) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 18/150
#   train: mse=0.005463  mae=0.048159
#   valid: mse=0.005177  mae=0.046319  psnr=22.87 dB
#   ↑ new best (mse 0.005177) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 19/150
#   train: mse=0.005267  mae=0.047132
#   valid: mse=0.004886  mae=0.046537  psnr=23.12 dB
#   ↑ new best (mse 0.004886) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 20/150
#   train: mse=0.005013  mae=0.046650
#   valid: mse=0.004758  mae=0.045310  psnr=23.24 dB
#   ↑ new best (mse 0.004758) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 21/150
#   train: mse=0.004943  mae=0.046274
#   valid: mse=0.004687  mae=0.045177  psnr=23.31 dB
#   ↑ new best (mse 0.004687) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 22/150
#   train: mse=0.004746  mae=0.045581
#   valid: mse=0.004683  mae=0.044656  psnr=23.31 dB
#   ↑ new best (mse 0.004683) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 23/150
#   train: mse=0.004619  mae=0.044829
#   valid: mse=0.004473  mae=0.044579  psnr=23.50 dB
#   ↑ new best (mse 0.004473) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 24/150
#   train: mse=0.004630  mae=0.044817
#   valid: mse=0.004488  mae=0.042002  psnr=23.50 dB
#
# [train] Epoch 25/150
#   train: mse=0.004491  mae=0.043628
#   valid: mse=0.004116  mae=0.042753  psnr=23.86 dB
#   ↑ new best (mse 0.004116) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 26/150
#   train: mse=0.004089  mae=0.041153
#   valid: mse=0.004052  mae=0.040748  psnr=23.94 dB
#   ↑ new best (mse 0.004052) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 27/150
#   train: mse=0.004013  mae=0.040512
#   valid: mse=0.003603  mae=0.039455  psnr=24.44 dB
#   ↑ new best (mse 0.003603) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 28/150
#   train: mse=0.003949  mae=0.040482
#   valid: mse=0.004024  mae=0.039439  psnr=23.97 dB
#
# [train] Epoch 29/150
#   train: mse=0.003658  mae=0.038236
#   valid: mse=0.003485  mae=0.036507  psnr=24.59 dB
#   ↑ new best (mse 0.003485) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 30/150
#   train: mse=0.003677  mae=0.038240
#   valid: mse=0.003273  mae=0.035405  psnr=24.86 dB
#   ↑ new best (mse 0.003273) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 31/150
#   train: mse=0.003604  mae=0.038486
#   valid: mse=0.003541  mae=0.038664  psnr=24.51 dB
#
# [train] Epoch 32/150
#   train: mse=0.003538  mae=0.037971
#   valid: mse=0.003228  mae=0.035212  psnr=24.92 dB
#   ↑ new best (mse 0.003228) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 33/150
#   train: mse=0.003190  mae=0.035304
#   valid: mse=0.003038  mae=0.034437  psnr=25.18 dB
#   ↑ new best (mse 0.003038) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 34/150
#   train: mse=0.003148  mae=0.035164
#   valid: mse=0.003461  mae=0.035520  psnr=24.62 dB
#
# [train] Epoch 35/150
#   train: mse=0.003109  mae=0.034982
#   valid: mse=0.002848  mae=0.033454  psnr=25.46 dB
#   ↑ new best (mse 0.002848) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 36/150
#   train: mse=0.002855  mae=0.033123
#   valid: mse=0.002944  mae=0.034021  psnr=25.32 dB
#
# [train] Epoch 37/150
#   train: mse=0.002991  mae=0.034043
#   valid: mse=0.002804  mae=0.032731  psnr=25.53 dB
#   ↑ new best (mse 0.002804) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 38/150
#   train: mse=0.002845  mae=0.033043
#   valid: mse=0.002620  mae=0.031865  psnr=25.82 dB
#   ↑ new best (mse 0.002620) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 39/150
#   train: mse=0.002770  mae=0.032248
#   valid: mse=0.002587  mae=0.031924  psnr=25.88 dB
#   ↑ new best (mse 0.002587) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 40/150
#   train: mse=0.002777  mae=0.033274
#   valid: mse=0.003416  mae=0.040824  psnr=24.67 dB
#
# [train] Epoch 41/150
#   train: mse=0.003337  mae=0.037303
#   valid: mse=0.002726  mae=0.031989  psnr=25.65 dB
#
# [train] Epoch 42/150
#   train: mse=0.002744  mae=0.032333
#   valid: mse=0.002594  mae=0.032080  psnr=25.87 dB
#
# [train] Epoch 43/150
#   train: mse=0.002640  mae=0.031919
#   valid: mse=0.003210  mae=0.037429  psnr=24.96 dB
#
# [train] Epoch 44/150
#   train: mse=0.002660  mae=0.031779
#   valid: mse=0.002454  mae=0.029985  psnr=26.12 dB
#   ↑ new best (mse 0.002454) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 45/150
#   train: mse=0.002411  mae=0.029995
#   valid: mse=0.002270  mae=0.028471  psnr=26.46 dB
#   ↑ new best (mse 0.002270) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 46/150
#   train: mse=0.002276  mae=0.028483
#   valid: mse=0.002122  mae=0.028169  psnr=26.74 dB
#   ↑ new best (mse 0.002122) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 47/150
#   train: mse=0.002212  mae=0.028301
#   valid: mse=0.002210  mae=0.028803  psnr=26.56 dB
#
# [train] Epoch 48/150
#   train: mse=0.002223  mae=0.028236
#   valid: mse=0.002179  mae=0.027967  psnr=26.63 dB
#
# [train] Epoch 49/150
#   train: mse=0.002308  mae=0.028762
#   valid: mse=0.002330  mae=0.029230  psnr=26.33 dB
#
# [train] Epoch 50/150
#   train: mse=0.002229  mae=0.028498
#   valid: mse=0.002187  mae=0.028771  psnr=26.61 dB
#
# [train] Epoch 51/150
#   train: mse=0.002082  mae=0.027516
#   valid: mse=0.002017  mae=0.028320  psnr=26.96 dB
#   ↑ new best (mse 0.002017) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 52/150
#   train: mse=0.002021  mae=0.027469
#   valid: mse=0.001980  mae=0.028916  psnr=27.05 dB
#   ↑ new best (mse 0.001980) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 53/150
#   train: mse=0.001948  mae=0.027013
#   valid: mse=0.002008  mae=0.028921  psnr=26.97 dB
#
# [train] Epoch 54/150
#   train: mse=0.001889  mae=0.026871
#   valid: mse=0.001859  mae=0.027967  psnr=27.31 dB
#   ↑ new best (mse 0.001859) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 55/150
#   train: mse=0.001727  mae=0.025895
#   valid: mse=0.001728  mae=0.026477  psnr=27.63 dB
#   ↑ new best (mse 0.001728) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 56/150
#   train: mse=0.001853  mae=0.026811
#   valid: mse=0.001807  mae=0.026878  psnr=27.44 dB
#
# [train] Epoch 57/150
#   train: mse=0.001691  mae=0.026182
#   valid: mse=0.001787  mae=0.027403  psnr=27.49 dB
#
# [train] Epoch 58/150
#   train: mse=0.001708  mae=0.026147
#   valid: mse=0.001624  mae=0.025132  psnr=27.90 dB
#   ↑ new best (mse 0.001624) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 59/150
#   train: mse=0.001485  mae=0.024127
#   valid: mse=0.001515  mae=0.025442  psnr=28.20 dB
#   ↑ new best (mse 0.001515) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 60/150
#   train: mse=0.001621  mae=0.024801
#   valid: mse=0.001597  mae=0.025537  psnr=27.98 dB
#
# [train] Epoch 61/150
#   train: mse=0.001495  mae=0.024166
#   valid: mse=0.001439  mae=0.024851  psnr=28.44 dB
#   ↑ new best (mse 0.001439) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 62/150
#   train: mse=0.001372  mae=0.023434
#   valid: mse=0.001379  mae=0.024522  psnr=28.61 dB
#   ↑ new best (mse 0.001379) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 63/150
#   train: mse=0.001296  mae=0.022687
#   valid: mse=0.001330  mae=0.023691  psnr=28.77 dB
#   ↑ new best (mse 0.001330) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 64/150
#   train: mse=0.001371  mae=0.023081
#   valid: mse=0.001420  mae=0.025690  psnr=28.49 dB
#
# [train] Epoch 65/150
#   train: mse=0.001249  mae=0.022190
#   valid: mse=0.001196  mae=0.022959  psnr=29.24 dB
#   ↑ new best (mse 0.001196) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 66/150
#   train: mse=0.001238  mae=0.022565
#   valid: mse=0.001175  mae=0.022906  psnr=29.31 dB
#   ↑ new best (mse 0.001175) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 67/150
#   train: mse=0.001300  mae=0.023269
#   valid: mse=0.001377  mae=0.024407  psnr=28.63 dB
#
# [train] Epoch 68/150
#   train: mse=0.001256  mae=0.022284
#   valid: mse=0.001218  mae=0.023820  psnr=29.17 dB
#
# [train] Epoch 69/150
#   train: mse=0.001145  mae=0.021171
#   valid: mse=0.001179  mae=0.022838  psnr=29.30 dB
#
# [train] Epoch 70/150
#   train: mse=0.001115  mae=0.021005
#   valid: mse=0.001120  mae=0.022874  psnr=29.52 dB
#   ↑ new best (mse 0.001120) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 71/150
#   train: mse=0.000937  mae=0.019504
#   valid: mse=0.001099  mae=0.022167  psnr=29.60 dB
#   ↑ new best (mse 0.001099) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 72/150
#   train: mse=0.001044  mae=0.020549
#   valid: mse=0.001197  mae=0.023382  psnr=29.22 dB
#
# [train] Epoch 73/150
#   train: mse=0.001147  mae=0.022106
#   valid: mse=0.001135  mae=0.023022  psnr=29.46 dB
#
# [train] Epoch 74/150
#   train: mse=0.000921  mae=0.019899
#   valid: mse=0.001042  mae=0.022662  psnr=29.84 dB
#   ↑ new best (mse 0.001042) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 75/150
#   train: mse=0.000870  mae=0.019161
#   valid: mse=0.000956  mae=0.021312  psnr=30.20 dB
#   ↑ new best (mse 0.000956) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 76/150
#   train: mse=0.000841  mae=0.018669
#   valid: mse=0.000964  mae=0.021213  psnr=30.19 dB
#
# [train] Epoch 77/150
#   train: mse=0.000860  mae=0.018755
#   valid: mse=0.000936  mae=0.020750  psnr=30.29 dB
#   ↑ new best (mse 0.000936) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 78/150
#   train: mse=0.000884  mae=0.019070
#   valid: mse=0.000921  mae=0.021023  psnr=30.37 dB
#   ↑ new best (mse 0.000921) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 79/150
#   train: mse=0.000820  mae=0.018399
#   valid: mse=0.001024  mae=0.022001  psnr=29.90 dB
#
# [train] Epoch 80/150
#   train: mse=0.000898  mae=0.019107
#   valid: mse=0.000923  mae=0.020884  psnr=30.37 dB
#
# [train] Epoch 81/150
#   train: mse=0.000949  mae=0.019346
#   valid: mse=0.001040  mae=0.022028  psnr=29.85 dB
#
# [train] Epoch 82/150
#   train: mse=0.000826  mae=0.018537
#   valid: mse=0.000914  mae=0.020978  psnr=30.41 dB
#   ↑ new best (mse 0.000914) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 83/150
#   train: mse=0.000760  mae=0.017796
#   valid: mse=0.000942  mae=0.021061  psnr=30.27 dB
#
# [train] Epoch 84/150
#   train: mse=0.000839  mae=0.018854
#   valid: mse=0.000913  mae=0.020896  psnr=30.40 dB
#   ↑ new best (mse 0.000913) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 85/150
#   train: mse=0.000753  mae=0.017829
#   valid: mse=0.000879  mae=0.020396  psnr=30.58 dB
#   ↑ new best (mse 0.000879) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 86/150
#   train: mse=0.000738  mae=0.017914
#   valid: mse=0.000885  mae=0.020795  psnr=30.54 dB
#
# [train] Epoch 87/150
#   train: mse=0.000760  mae=0.017801
#   valid: mse=0.000933  mae=0.020718  psnr=30.31 dB
#
# [train] Epoch 88/150
#   train: mse=0.000707  mae=0.017226
#   valid: mse=0.000820  mae=0.019790  psnr=30.88 dB
#   ↑ new best (mse 0.000820) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 89/150
#   train: mse=0.000782  mae=0.017650
#   valid: mse=0.000970  mae=0.021880  psnr=30.15 dB
#
# [train] Epoch 90/150
#   train: mse=0.000778  mae=0.018007
#   valid: mse=0.000848  mae=0.020417  psnr=30.74 dB
#
# [train] Epoch 91/150
#   train: mse=0.000657  mae=0.016729
#   valid: mse=0.000768  mae=0.019600  psnr=31.16 dB
#   ↑ new best (mse 0.000768) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 92/150
#   train: mse=0.000649  mae=0.016522
#   valid: mse=0.000812  mae=0.020080  psnr=30.93 dB
#
# [train] Epoch 93/150
#   train: mse=0.000619  mae=0.016204
#   valid: mse=0.000822  mae=0.020015  psnr=30.87 dB
#
# [train] Epoch 94/150
#   train: mse=0.000725  mae=0.016983
#   valid: mse=0.001019  mae=0.021790  psnr=29.93 dB
#
# [train] Epoch 95/150
#   train: mse=0.000720  mae=0.016987
#   valid: mse=0.000889  mae=0.020240  psnr=30.54 dB
#
# [train] Epoch 96/150
#   train: mse=0.000630  mae=0.016328
#   valid: mse=0.000756  mae=0.019473  psnr=31.24 dB
#   ↑ new best (mse 0.000756) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 97/150
#   train: mse=0.000612  mae=0.016151
#   valid: mse=0.000853  mae=0.020487  psnr=30.70 dB
#
# [train] Epoch 98/150
#   train: mse=0.000636  mae=0.016307
#   valid: mse=0.000809  mae=0.019639  psnr=30.93 dB
#
# [train] Epoch 99/150
#   train: mse=0.000631  mae=0.016466
#   valid: mse=0.000787  mae=0.019419  psnr=31.05 dB
#
# [train] Epoch 100/150
#   train: mse=0.000657  mae=0.016390
#   valid: mse=0.000766  mae=0.019222  psnr=31.16 dB
#
# [train] Epoch 101/150
#   train: mse=0.000658  mae=0.016638
#   valid: mse=0.000892  mae=0.021204  psnr=30.51 dB
#
# [train] Epoch 102/150
#   train: mse=0.000619  mae=0.016134
#   valid: mse=0.000904  mae=0.021128  psnr=30.46 dB
#
# [train] Epoch 103/150
#   train: mse=0.000631  mae=0.016283
#   valid: mse=0.000693  mae=0.018514  psnr=31.60 dB
#   ↑ new best (mse 0.000693) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 104/150
#   train: mse=0.000574  mae=0.015577
#   valid: mse=0.000729  mae=0.019134  psnr=31.39 dB
#
# [train] Epoch 105/150
#   train: mse=0.000545  mae=0.015230
#   valid: mse=0.000831  mae=0.019978  psnr=30.82 dB
#
# [train] Epoch 106/150
#   train: mse=0.000572  mae=0.015622
#   valid: mse=0.000769  mae=0.019507  psnr=31.17 dB
#
# [train] Epoch 107/150
#   train: mse=0.000590  mae=0.015617
#   valid: mse=0.001002  mae=0.021472  psnr=30.02 dB
#
# [train] Epoch 108/150
#   train: mse=0.000612  mae=0.015945
#   valid: mse=0.000750  mae=0.019407  psnr=31.28 dB
#
# [train] Epoch 109/150
#   train: mse=0.000556  mae=0.015729
#   valid: mse=0.000709  mae=0.018629  psnr=31.51 dB
#
# [train] Epoch 110/150
#   train: mse=0.000524  mae=0.014992
#   valid: mse=0.000804  mae=0.019701  psnr=30.98 dB
#
# [train] Epoch 111/150
#   train: mse=0.000589  mae=0.015663
#   valid: mse=0.000837  mae=0.020022  psnr=30.80 dB
#
# [train] Epoch 112/150
#   train: mse=0.000588  mae=0.015475
#   valid: mse=0.000771  mae=0.019315  psnr=31.17 dB
#
# [train] Epoch 113/150
#   train: mse=0.000506  mae=0.014642
#   valid: mse=0.000642  mae=0.017875  psnr=31.94 dB
#   ↑ new best (mse 0.000642) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 114/150
#   train: mse=0.000540  mae=0.015036
#   valid: mse=0.000842  mae=0.019685  psnr=30.77 dB
#
# [train] Epoch 115/150
#   train: mse=0.000580  mae=0.015522
#   valid: mse=0.000674  mae=0.018432  psnr=31.74 dB
#
# [train] Epoch 116/150
#   train: mse=0.000517  mae=0.014911
#   valid: mse=0.000700  mae=0.018798  psnr=31.56 dB
#
# [train] Epoch 117/150
#   train: mse=0.000536  mae=0.015143
#   valid: mse=0.000744  mae=0.019073  psnr=31.31 dB
#
# [train] Epoch 118/150
#   train: mse=0.000587  mae=0.015478
#   valid: mse=0.000757  mae=0.019133  psnr=31.22 dB
#
# [train] Epoch 119/150
#   train: mse=0.000541  mae=0.015017
#   valid: mse=0.000657  mae=0.018168  psnr=31.84 dB
#
# [train] Epoch 120/150
#   train: mse=0.000484  mae=0.014539
#   valid: mse=0.000805  mae=0.020358  psnr=30.97 dB
#
# [train] Epoch 121/150
#   train: mse=0.000540  mae=0.015449
#   valid: mse=0.000682  mae=0.018447  psnr=31.67 dB
#
# [train] Epoch 122/150
#   train: mse=0.000537  mae=0.015332
#   valid: mse=0.000709  mae=0.018516  psnr=31.52 dB
#
# [train] Epoch 123/150
#   train: mse=0.000503  mae=0.014687
#   valid: mse=0.000810  mae=0.019025  psnr=30.93 dB
#
# [train] Epoch 124/150
#   train: mse=0.000524  mae=0.014669
#   valid: mse=0.000638  mae=0.017940  psnr=31.96 dB
#   ↑ new best (mse 0.000638) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 125/150
#   train: mse=0.000480  mae=0.014368
#   valid: mse=0.000739  mae=0.019498  psnr=31.36 dB
#
# [train] Epoch 126/150
#   train: mse=0.000465  mae=0.014248
#   valid: mse=0.000647  mae=0.018223  psnr=31.91 dB
#
# [train] Epoch 127/150
#   train: mse=0.000520  mae=0.014690
#   valid: mse=0.000859  mae=0.019990  psnr=30.69 dB
#
# [train] Epoch 128/150
#   train: mse=0.000506  mae=0.014836
#   valid: mse=0.000702  mae=0.018683  psnr=31.56 dB
#
# [train] Epoch 129/150
#   train: mse=0.000546  mae=0.014929
#   valid: mse=0.000851  mae=0.020538  psnr=30.72 dB
#
# [train] Epoch 130/150
#   train: mse=0.000503  mae=0.014767
#   valid: mse=0.000672  mae=0.018405  psnr=31.73 dB
#
# [train] Epoch 131/150
#   train: mse=0.000439  mae=0.013823
#   valid: mse=0.000685  mae=0.018436  psnr=31.66 dB
#
# [train] Epoch 132/150
#   train: mse=0.000450  mae=0.013805
#   valid: mse=0.000702  mae=0.018140  psnr=31.56 dB
#
# [train] Epoch 133/150
#   train: mse=0.000433  mae=0.013635
#   valid: mse=0.000636  mae=0.017946  psnr=31.97 dB
#   ↑ new best (mse 0.000636) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 134/150
#   train: mse=0.000432  mae=0.013646
#   valid: mse=0.000666  mae=0.018816  psnr=31.80 dB
#
# [train] Epoch 135/150
#   train: mse=0.000482  mae=0.014296
#   valid: mse=0.000670  mae=0.018304  psnr=31.75 dB
#
# [train] Epoch 136/150
#   train: mse=0.000450  mae=0.013915
#   valid: mse=0.000664  mae=0.018506  psnr=31.81 dB
#
# [train] Epoch 137/150
#   train: mse=0.000445  mae=0.013893
#   valid: mse=0.000615  mae=0.017713  psnr=32.14 dB
#   ↑ new best (mse 0.000615) -> runs/ae1024_tensor/ckpts/best.pt
#
# [train] Epoch 138/150
#   train: mse=0.000434  mae=0.013916
#   valid: mse=0.000645  mae=0.018250  psnr=31.94 dB
#
# [train] Epoch 139/150
#   train: mse=0.000471  mae=0.014742
#   valid: mse=0.000708  mae=0.019109  psnr=31.53 dB
#
# [train] Epoch 140/150
#   train: mse=0.000556  mae=0.015640
#   valid: mse=0.000732  mae=0.019134  psnr=31.36 dB
#
# [train] Epoch 141/150
#   train: mse=0.000600  mae=0.015444
#   valid: mse=0.000728  mae=0.018642  psnr=31.39 dB
#
# [train] Epoch 142/150
#   train: mse=0.000645  mae=0.015340
#   valid: mse=0.000798  mae=0.019423  psnr=31.01 dB
#
# [train] Epoch 143/150
#   train: mse=0.000579  mae=0.015651
#   valid: mse=0.000757  mae=0.019811  psnr=31.21 dB
#
# [train] Epoch 144/150
#   train: mse=0.000479  mae=0.014401
#   valid: mse=0.000657  mae=0.017804  psnr=31.85 dB
#
# [train] Epoch 145/150
#   train: mse=0.000459  mae=0.013746
#   valid: mse=0.000625  mae=0.017718  psnr=32.05 dB
#
# [train] Epoch 146/150
#   train: mse=0.000441  mae=0.013607
#   valid: mse=0.000633  mae=0.017472  psnr=32.02 dB
#
# [train] Epoch 147/150
#   train: mse=0.000403  mae=0.013158
#   valid: mse=0.000627  mae=0.017772  psnr=32.04 dB
#
# [train] Epoch 148/150
#   train: mse=0.000403  mae=0.013181
#   valid: mse=0.000618  mae=0.017888  psnr=32.10 dB
#
# [train] Epoch 149/150
#   train: mse=0.000382  mae=0.012978
#   valid: mse=0.000664  mae=0.018357  psnr=31.78 dB
#
# [train] Epoch 150/150
#   train: mse=0.000464  mae=0.013867
#   valid: mse=0.000671  mae=0.017933  psnr=31.76 dB
# Best ckpt: runs/ae1024_tensor/ckpts/best.pt

# %%
evaluate(model,val_ld,"cuda",sample_dir="positive")
# Out:
# {'mse': 0.00043633682335811585, 'mae': 0.013116729022427038}

# %%
evaluate(model,negative,"cuda",sample_dir="negative")
# Out:
# {'mse': 0.004291121783242464, 'mae': 0.046508773152108204}

# %%
import os
import torch
from torchvision.utils import save_image

@torch.no_grad()
def save_recon_diffs(
    model, loader,
    outdir="dif", device=None, suffix="neg",
    max_samples=100
):
    """
    Save combined images: [original | reconstruction | abs diff].
    - Diff is grayscale (mean over channels).
    - max_samples limits how many to save.
    """
    os.makedirs(outdir, exist_ok=True)
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device).eval()

    def _get_imgs_from_batch(batch):
        return batch[0] if isinstance(batch, (tuple, list)) else batch

    counter = 0
    for batch in loader:
        imgs = _get_imgs_from_batch(batch).to(device, non_blocking=True)  # [B,C,H,W]
        rec, _ = model(imgs)
        diff = (rec - imgs).abs().mean(dim=1, keepdim=True)               # [B,1,H,W]
        diff = diff.repeat(1, 3, 1, 1)                                    # -> 3-channel for saving

        for i in range(imgs.size(0)):
            if counter >= max_samples:
                print(f"[done] Saved {counter} samples to: {outdir}")
                return
            base = f"{suffix}_{counter:06d}"
            # concat along width: [C,H,W] → (orig | recon | diff)
            row = torch.cat([imgs[i], rec[i], diff[i]], dim=2)
            save_image(row, os.path.join(outdir, f"triple_{base}.png"))
            counter += 1

    print(f"[done] Saved {counter} samples to: {outdir}")

save_recon_diffs(model, negative, outdir="negdif", suffix="", max_samples=50)
save_recon_diffs(model, val_ld, outdir="posdif", suffix="", max_samples=50)
# Out:
# [done] Saved 50 samples to: negdif
# [done] Saved 50 samples to: posdif

# %%
import torch.nn as nn
import os, math, torch
import torch.nn.functional as F
from torchvision import utils as vutils

@torch.no_grad()
def evaluate(model, loader, device, sample_dir=None, epoch=0, max_grids=1, grid_n=40):
    model.eval()
    totals = {'mse': 0.0, 'mae': 0.0}
    count, saved = 0, 0
    for batch in loader:
        imgs = batch[0].to(device, non_blocking=True)
        rec, _ = model(imgs)
        mse = F.mse_loss(rec, imgs, reduction='mean').item()
        mae = F.l1_loss(rec, imgs, reduction='mean').item()
        b = imgs.size(0)
        totals['mse'] += mse * b
        totals['mae'] += mae * b
        count += b
        
        if sample_dir and saved < max_grids:
            grid = vutils.make_grid(torch.cat([imgs[:grid_n], rec[:grid_n]], dim=0), nrow=grid_n)
            os.makedirs(sample_dir, exist_ok=True)
            vutils.save_image(grid, os.path.join(sample_dir, f"val_ep{epoch:03d}_{saved:02d}.png"))
            saved += 1
            
    if count == 0:
        return {k: float("nan") for k in totals}
    return {k: v / count for k, v in totals.items()}

class DownBlock(nn.Module):
    """Conv -> GroupNorm -> SiLU, with optional downsampling via stride."""

    def __init__(self, in_ch, out_ch, stride=1):
        super().__init__()
        self.block = nn.Sequential(nn.Conv2d(in_ch, out_ch, kernel_size=3, stride=stride, padding=1, bias=False),
                                   nn.GroupNorm(num_groups=min(8, out_ch), num_channels=out_ch), nn.SiLU(inplace=True),
                                   nn.Conv2d(out_ch, out_ch, kernel_size=3, stride=1, padding=1, bias=False),
                                   nn.GroupNorm(num_groups=min(8, out_ch), num_channels=out_ch),
                                   nn.SiLU(inplace=True), )

    def forward(self, x):
        return self.block(x)


class UpBlock(nn.Module):
    """Upsample by 2x (ConvT) -> Conv block."""

    def __init__(self, in_ch, out_ch):
        super().__init__()

        self.block = nn.Sequential(nn.ConvTranspose2d(in_ch, out_ch, kernel_size=4, stride=2, padding=1, bias=False),
                                   nn.GroupNorm(num_groups=min(8, out_ch), num_channels=out_ch), nn.SiLU(inplace=True),
                                   nn.Conv2d(out_ch, out_ch, kernel_size=3, stride=1, padding=1, bias=False),
                                   nn.GroupNorm(num_groups=min(8, out_ch), num_channels=out_ch),
                                   nn.SiLU(inplace=True), )

    def forward(self, x):
        return self.block(x)


# ---------- the autoencoder ----------


class AutoEncoder(nn.Module):
    """
    Fully convolutional 5-stage AE for 256x256 using ONLY DownBlock/UpBlock.
      Encoder: 256 -> 128 -> 64 -> 32 -> 16 -> 8    (DownBlock x5)
      Bottleneck: (ch5, 8, 8)
      Decoder: 8 -> 16 -> 32 -> 64 -> 128 -> 256    (UpBlock x5)
    """
    def __init__(self, in_channels: int = 3, base_ch: int = 32):
        super().__init__()
        ch1 = base_ch          # 32
        ch2 = base_ch * 2      # 64
        ch3 = base_ch * 4      # 128
        ch4 = base_ch * 8      # 256
        ch5 = base_ch * 16     # 512

        # Encoder
        self.enc1 = DownBlock(in_channels, ch1, stride=2)   # 256 -> 128
        self.enc2 = DownBlock(ch1,        ch2, stride=2)    # 128 -> 64
        self.enc3 = DownBlock(ch2,        ch3, stride=2)    # 64  -> 32
        self.enc4 = DownBlock(ch3,        ch4, stride=2)    # 32  -> 16
        self.enc5 = DownBlock(ch4,        ch5, stride=2)    # 16  -> 8

        # Decoder (mirror)
        self.dec1 = UpBlock(ch5, ch4)   # 8  -> 16
        self.dec2 = UpBlock(ch4, ch3)   # 16 -> 32
        self.dec3 = UpBlock(ch3, ch2)   # 32 -> 64
        self.dec4 = UpBlock(ch2, ch1)   # 64 -> 128
        self.dec5 = UpBlock(ch1, ch1)   # 128 -> 256

        # Output head
        self.out = nn.Sequential(
            nn.Conv2d(ch1, in_channels, kernel_size=1, stride=1, bias=True),
            nn.Sigmoid(),
        )

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
            elif isinstance(m, nn.GroupNorm):
                if m.weight is not None: nn.init.ones_(m.weight)
                if m.bias  is not None: nn.init.zeros_(m.bias)

    def encode(self, x):
        x = self.enc1(x)  # [B, ch1,128,128]
        x = self.enc2(x)  # [B, ch2, 64, 64]
        x = self.enc3(x)  # [B, ch3, 32, 32]
        x = self.enc4(x)  # [B, ch4, 16, 16]
        x = self.enc5(x)  # [B, ch5,  8,  8]
        return x

    def decode(self, h):
        x = self.dec1(h)  # [B, ch4, 16,16]
        x = self.dec2(x)  # [B, ch3, 32,32]
        x = self.dec3(x)  # [B, ch2, 64,64]
        x = self.dec4(x)  # [B, ch1,128,128]
        x = self.dec5(x)  # [B, ch1,256,256]
        return self.out(x)

    def forward(self, x):
        h = self.encode(x)
        x_rec = self.decode(h)
        return x_rec, h
